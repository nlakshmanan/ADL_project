# %% [markdown]
# <a href="https://colab.research.google.com/github/nlakshmanan/ADL_project/blob/master/House_Sales_in_King_County_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data location - /content/drive/My Drive/ColabData/housesalesprediction/kc_house_data.csv
